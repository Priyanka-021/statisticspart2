# %% [markdown]
# #**Statistics Part 2**

# %% [markdown]
# **1.What is hypothesis testing in statistics?**
#
#   Hypothesis is a claim or statement or an assumption about a population parameter that can be tested using statistical methods. Take a sample calculate avg age of sample and check if the sample avg age is close to the claim that you have made about population.
#
# **2. What is the null hypothesis, and how does it differ from the alternative hypothesis?**
#
#   Null hypothesis is initial default assumption that there is no effect, no difference, or no relationship between variables.and its opposite assumtion is alternate hypothesis i.e This is the statement that contradicts the null hypothesis and reflects the effect or difference the researcher expects or wants to prove.
#
# **3.What is the significance level in hypothesis testing, and why is it important?**
#
#   The significance level in hypothesis testing, often denoted by α (alpha), is the threshold for deciding whether to reject the null hypothesis. It is important because it controls error rate, decision threshold, Standardizes results.
#
# **4.What does a P-value represent in hypothesis testing?**
#
#   The p-value is the probability value, calculated from a statistical test. In hypothesis testing, a p-value (probability value) represents the probability of observing your sample data—or something more extreme—assuming that the null hypothesis is true.
#
# **5.How do you interpret the P-value in hypothesis testing?**
#
#   P-value in hypothesis testing is used to decide whether to reject the null hypothesis or not.
#
# **6.What are Type 1 and Type 2 errors in hypothesis testing?**
#
#   Type 1 error is the rejection of null hypothesis when it is actually true.
#   Type 2 error is fail to reject the null hypothesis when that is actually false.
#
# **7.What is the difference between a one-tailed and a two-tailed test in hypothesis testing?**
#
#   The difference between a one-tailed and a two-tailed test in hypothesis testing lies in what kind of effect you're testing for — whether you're checking for a specific direction or any difference at all. One-Tailed Test
#   for an effect in only one direction (either greater than or less than).
#   Two-Tailed Test for an effect in both directions (any difference).
#
# **8.What is the Z-test, and when is it used in hypothesis testing?**
#
#   The Z-test is a type of statistical test used to determine whether there is a significant difference between sample and population means (or between two sample means), when the population standard deviation is known and the sample size is large (typically n ≥ 30).
#
# **9.How do you calculate the Z-score, and what does it represent in hypothesis testing?**
#
#   The Z-score is a statistical measure that tells you how many standard deviations a data point (or sample mean) is from the population mean. In hypothesis testing, it's used to determine whether your sample result is significantly different from what you'd expect under the null hypothesis.
#
#  Z-Score Formula: Z=𝑋−𝜇/(sigma/(n)^1/2)
#
# **10.What is the T-distribution, and when should it be used instead of the normal distribution?**
#
#   The T-distribution (also called Student's t-distribution) is a probability distribution used in statistics when the sample size is small (n < 30) and the population standard deviation (σ) is unknown. It's similar in shape to the normal distribution, but has heavier tails, meaning it accounts for more variability in smaller samples
#
# **11.What is the difference between a Z-test and a T-test?**
#
#   When sample size is greater than 30 and standard deviation of population is given , use z test if otherwise t test is used
#
# **12.What is the T-test, and how is it used in hypothesis testing?**
#
#   A T-test is a statistical test used to compare means and determine whether differences between groups are statistically significant.T-test in Hypothesis Testing the T-test helps decide if the difference between groups is likely due to chance or a real effect.
#
# **13.What is the relationship between Z-test and T-test in hypothesis testing?**
#
#   The Z-test and T-test are both used in hypothesis testing to determine whether a sample statistic (like a mean) significantly differs from a population parameter or another sample. The T-test is essentially a more flexible version of the Z-test, designed to handle small samples and unknown population standard deviations
#
# **14.What is a confidence interval, and how is it used to interpret statistical results?**
#
#   A confidence interval is a range of values that's likely to contain a population parameter (like the mean) with a certain level of confidence. It is used in statistical results It gives a range, not just a single value — more informative. Helps judge the precision of an estimate. Can help decide statistical significance:
#
# **15.What is the margin of error, and how does it affect the confidence interval?**
#
#   The margin of error is the amount you're allowed to be off from the sample estimate when estimating a population parameter (like the mean or proportion).
#   It defines how wide the confidence interval is.
#
# **16.How is Bayes' Theorem used in statistics, and what is its significance?**
#
#   Bayes' Theorem is a fundamental concept in probability and statistics that allows to calculate the probability of certain event when one condition is already true. It is used in email filters use Bayes' Theorem to calculate the probability that an email is spam based on the presence of certain words. In court, Bayes' Theorem can be used to evaluate the probability of guilt given evidence (although its use in law is debated)
#
# **17.What is the Chi-square distribution, and when is it used?**
#
#   The chi_square distribution is a probability distribution that discribes the distribution of a sum of square of a k random varibale. It is used when Chi-square Test of Independence checks if two categorical variables are independent or associated. Chi-square Goodness-of-Fit Test, Tests whether an observed frequency distribution matches an expected distribution. Chi-square Test for Homogeneity and Chi-square Test for Homogeneity.
#
# **18.What is the Chi-square goodness of fit test, and how is it applied?**
#
#   The Chi-square goodness of fit test is a statistical test used to determine whether a set of observed categorical data matches an expected distribution. It's particularly useful when you want to see if your data follows a specific theoretical distribution (like uniform, binomial, or any custom distribution).
#   Steps to Apply the Test
#   Define Hypotheses:
#   Null hypothesis Observed data follows the expected distribution.
#   Alternative hypothesis Observed data does not follow the expected distribution.
#   Calculate Expected Frequencies under H not
#   Compute Chi-square Statistic using the formula above.
#   Determine Degrees of Freedom (df):
#   Find the p-value from the Chi-square distribution table (or using software).
#   Compare p-value to significance level.
#
# **19.What is the F-distribution, and when is it used in hypothesis testing?**
#
#   The F-distribution is a probability distribution that arises frequently in hypothesis testing, particularly when comparing variances or analyzing multiple groups. It is a right-skewed, continuous distribution.
#   It depends on two degrees of freedom: one for the numerator and one for the denominator. It is non-negative (starts at 0 and goes to infinity)
#   The F-Distribution  is used-:
#   Testing Equality of Variances
#   F-test for variances: Used to compare two population variances
#   Analysis of Variance (ANOVA)- The most common application. Used to test if three or more population means are equal.
#   Regression Analysis- The F-test in regression assesses whether the overall regression model is a good fit.
#
# **20.What is an ANOVA test, and what are its assumptions?**
#
#   The ANOVA test (Analysis of Variance) is a statistical method used to determine whether there are statistically significant differences between the means of three or more independent groups. ANOVA compares the variance between groups to the variance within groups. If the between-group variance is significantly larger, it suggests that at least one group mean is different from the others.
#   Assumptions of ANOVA
#   1.Independence of observations- Each sample is collected independently.
#      No repeated measures unless using repeated measures ANOVA.
#   2.Normality- The data in each group are approximately normally distributed.
#      ANOVA is robust to mild deviations from normality if sample sizes are large.
#   3.Homogeneity of variances (homoscedasticity)- All groups have equal
#      variances.Can be tested using Levene's Test or Bartlett's Tes
#
# **21.What are the different types of ANOVA tests?**
#
#   There are several types of ANOVA (Analysis of Variance) tests, each designed to handle different experimental designs and types of data. The main types are categorized by the number of independent variables (factors) and whether the same subjects are used across different conditions.
#   1.One-Way ANOVA
#   2.Two-Way ANOVA
#   3.Repeated Measures ANOVA
#   4.Factorial ANOVA
#
# **22.What is the F-test, and how does it relate to hypothesis testing?**
#
#    The F-test evaluates whether the variance between groups is significantly greater than the variance within groups. If this ratio is significantly larger than 1, it suggests that the groups are not just different by chance.
#    Common Uses of the F-Test in Hypothesis Testing
#    1.Testing Equality of Variances- To test if two populations have equal variances.
#    2.Analysis of Variance (ANOVA)- To test if three or more group means are equal
#    3.Regression Model Significance- To test if the overall regression model is statistically significant.

# %% [markdown]
# #**Practical Part - 1**

# %% [markdown]
# **1.Write a Python program to generate a random variable and display its value?**

# %%
import random

random_variable = random.random()

print("Random variable value:", random_variable)
# Out:
# Random variable value: 0.6170452248681736

# %% [markdown]
# **2.Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

low = 1
high = 7
dist = randint(low, high)

x = np.arange(low, high)
pmf = dist.pmf(x)
plt.figure(figsize=(8, 5))
plt.stem(x, pmf, basefmt=" ")
plt.xlabel('Value')
plt.ylabel('Probability')
plt.title('PMF of Discrete Uniform Distribution (1 to 6)')
plt.xticks(x)
plt.grid(True)
plt.show()

# %% [markdown]
# **3.Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.**

# %%
def bernoulli_pdf(x, p):
    if x not in (0, 1):
        raise ValueError("x must be 0 or 1 for a Bernoulli distribution.")
    if not 0 <= p <= 1:
        raise ValueError("p must be a probability in the range [0, 1].")

    return p if x == 1 else 1 - p
print(bernoulli_pdf(1, 0.7))
# Out:
# 0.7

# %% [markdown]
# **4.Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.**

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 10
p = 0.5
samples = 10000
data = np.random.binomial(n, p, samples)

plt.figure(figsize=(8, 5))
plt.hist(data, bins=np.arange(n + 2) - 0.5, density=True, edgecolor='black')
plt.title('Binomial Distribution Histogram (n=10, p=0.5)')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(np.arange(0, n + 1))
plt.grid(True)
plt.show()

# %% [markdown]
# **5.Create a Poisson distribution and visualize it using Python.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

mu = 3
samples = 10000

data = np.random.poisson(mu, samples)

x = np.arange(0, 15)
pmf = poisson.pmf(x, mu)

plt.figure(figsize=(10, 6))
plt.hist(data, bins=np.arange(0, 16)-0.5, density=True, alpha=0.6, color='skyblue', label='Simulated Data')
plt.stem(x, pmf, linefmt='k-', markerfmt='ko', basefmt=" ", label='Theoretical PMF')
plt.title('Poisson Distribution (λ = 3)')
plt.xlabel('Number of Events')
plt.ylabel('Probability')
plt.xticks(x)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# **6.Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete
# uniform distribution.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

low = 1
high = 7
dist = randint(low, high)

x = np.arange(low, high)
cdf = dist.cdf(x)

plt.figure(figsize=(8, 5))
plt.step(x, cdf, where='post', label='CDF', color='blue')
plt.title('CDF of Discrete Uniform Distribution (1 to 6)')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.xticks(x)
plt.ylim(0, 1.1)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# **7.Generate a continuous uniform distribution using NumPy and visualize it.**

# %%
import numpy as np
import matplotlib.pyplot as plt
low = 0.0
high = 1.0
samples = 10000


data = np.random.uniform(low, high, samples)

plt.figure(figsize=(8, 5))
plt.hist(data, bins=50, density=True, edgecolor='black', alpha=0.7, color='green')
plt.title('Continuous Uniform Distribution (0.0 to 1.0)')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %% [markdown]
# **8.Simulate data from a normal distribution and plot its histogram.**

# %%
import numpy as np
import matplotlib.pyplot as plt

mean = 0
std_dev = 1
samples = 10000
data = np.random.normal(mean, std_dev, samples)

plt.figure(figsize=(8, 5))
plt.hist(data, bins=50, density=True, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Histogram of Simulated Normal Distribution (μ=0, σ=1)')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %% [markdown]
# **9.Write a Python function to calculate Z-scores from a dataset and plot them.**

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_z_scores(data):

    data = np.array(data)
    mean = np.mean(data)
    std = np.std(data)

    if std == 0:
        raise ValueError("Standard deviation is zero. Z-scores are undefined.")

    z_scores = (data - mean) / std

    plt.figure(figsize=(10, 5))
    plt.plot(z_scores, marker='o', linestyle='-', color='blue')
    plt.axhline(0, color='black', linestyle='--', linewidth=1)
    plt.axhline(1, color='green', linestyle='--', linewidth=1)
    plt.axhline(-1, color='green', linestyle='--', linewidth=1)
    plt.axhline(2, color='orange', linestyle='--', linewidth=1)
    plt.axhline(-2, color='orange', linestyle='--', linewidth=1)
    plt.axhline(3, color='red', linestyle='--', linewidth=1)
    plt.axhline(-3, color='red', linestyle='--', linewidth=1)
    plt.title('Z-scores of Dataset')
    plt.xlabel('Index')
    plt.ylabel('Z-score')
    plt.grid(True)
    plt.show()


data = np.random.normal(100, 15, 50)
z_scores = calculate_and_plot_z_scores(data)

# %% [markdown]
# **10.Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
population_size = 100000
lambda_exp = 1.0
sample_size = 30
num_samples = 10000

population = np.random.exponential(scale=1/lambda_exp, size=population_size)


sample_means = []
for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size)
    sample_means.append(np.mean(sample))


plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.hist(population, bins=50, color='skyblue', edgecolor='black', density=True)
plt.title('Original Exponential Distribution')
plt.xlabel('Value')
plt.ylabel('Density')


plt.subplot(1, 2, 2)
plt.hist(sample_means, bins=50, color='lightgreen', edgecolor='black', density=True)
plt.title(f'Distribution of Sample Means\n(n={sample_size}, {num_samples} samples)')
plt.xlabel('Sample Mean')
plt.ylabel('Density')

plt.tight_layout()
plt.show()

# %% [markdown]
# **11.Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.**

# %%
import numpy as np
import matplotlib.pyplot as plt


population_mean = 50
population_std = 10
population_size = 100000
population = np.random.normal(loc=population_mean, scale=population_std, size=population_size)


sample_size = 30
num_samples = 5000
sample_means = []


for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size, replace=False)
    sample_means.append(np.mean(sample))

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.hist(population, bins=50, color='skyblue', edgecolor='black', density=True)
plt.title('Original Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Density')

plt.subplot(1, 2, 2)
plt.hist(sample_means, bins=50, color='lightgreen', edgecolor='black', density=True)
plt.title(f'Distribution of Sample Means\n(n={sample_size}, {num_samples} samples)')
plt.xlabel('Sample Mean')
plt.ylabel('Density')

plt.tight_layout()
plt.show()

# %% [markdown]
# **12.Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal():

    x = np.linspace(-4, 4, 1000)

    y = norm.pdf(x, loc=0, scale=1)


    plt.figure(figsize=(8, 5))
    plt.plot(x, y, color='blue', label='Standard Normal PDF')
    plt.title('Standard Normal Distribution (μ = 0, σ = 1)')
    plt.xlabel('Z-score')
    plt.ylabel('Probability Density')
    plt.grid(True)

    plt.axvline(0, color='black', linestyle='--', linewidth=1, label='Mean (0)')
    plt.axvline(1, color='green', linestyle='--', linewidth=1, label='±1σ')
    plt.axvline(-1, color='green', linestyle='--', linewidth=1)
    plt.axvline(2, color='orange', linestyle='--', linewidth=1, label='±2σ')
    plt.axvline(-2, color='orange', linestyle='--', linewidth=1)
    plt.axvline(3, color='red', linestyle='--', linewidth=1, label='±3σ')
    plt.axvline(-3, color='red', linestyle='--', linewidth=1)
    plt.legend()
    plt.show()

# %% [markdown]
# **13.Generate random variables and calculate their corresponding probabilities using the binomial distribution.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

n = 10
p = 0.5
size = 1000

random_vars = np.random.binomial(n, p, size)

x = np.arange(0, n + 1)

pmf = binom.pmf(x, n, p)

plt.figure(figsize=(12, 6))


plt.subplot(1, 2, 1)
plt.hist(random_vars, bins=np.arange(n + 2) - 0.5, edgecolor='black', density=True)
plt.title('Histogram of Simulated Binomial Data')
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
plt.xticks(x)


plt.subplot(1, 2, 2)
plt.bar(x, pmf, color='skyblue', edgecolor='black')
plt.title('Binomial Distribution PMF')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(x)

plt.tight_layout()
plt.show()

# %% [markdown]
# **14.Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_and_plot_z_score(x, mean, std_dev):

    z = (x - mean) / std_dev
    print(f"Z-score for x = {x} (mean = {mean}, std = {std_dev}): {z:.3f}")

    p = norm.cdf(z)
    print(f"Probability of observing a value ≤ {x}: {p:.4f} ({p*100:.2f}%)")


    x_vals = np.linspace(-4, 4, 1000)
    y_vals = norm.pdf(x_vals)

    plt.figure(figsize=(10, 5))
    plt.plot(x_vals, y_vals, color='blue', label='Standard Normal PDF')
    plt.title('Standard Normal Distribution')
    plt.xlabel('Z-score')
    plt.ylabel('Probability Density')

    x_fill = np.linspace(-4, z, 1000)
    y_fill = norm.pdf(x_fill)
    plt.fill_between(x_fill, y_fill, color='skyblue', alpha=0.5, label=f'P(Z ≤ {z:.2f})')

    plt.axvline(z, color='red', linestyle='--', label=f'Z = {z:.2f}')
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# **15.Implement hypothesis testing using Z-statistics for a sample dataset.**

# %%
import math
from scipy.stats import norm

mu_0 = 70
sigma = 10
x_bar = 74
n = 30
alpha = 0.05


z = (x_bar - mu_0) / (sigma / math.sqrt(n))


z_critical = norm.ppf(1 - alpha)

p_value = 1 - norm.cdf(z)

if z > z_critical:
    result = "Reject the null hypothesis: There is evidence that the new method improves scores."
else:
    result = "Fail to reject the null hypothesis: No sufficient evidence for improvement."

print(f"Z-statistic: {z:.3f}")
print(f"Z-critical (0.05 level): {z_critical:.3f}")
print(f"P-value: {p_value:.4f}")
print(result)
# Out:
# Z-statistic: 2.191
# Z-critical (0.05 level): 1.645
# P-value: 0.0142
# Reject the null hypothesis: There is evidence that the new method improves scores.

# %% [markdown]
# **16.Create a confidence interval for a dataset using Python and interpret the result.**

# %%
import numpy as np
import scipy.stats as stats

data = [72, 75, 78, 70, 74, 77, 69, 73, 71, 76]


mean = np.mean(data)
sem = stats.sem(data)

confidence = 0.95
n = len(data)
df = n - 1
t_critical = stats.t.ppf((1 + confidence) / 2, df)

margin_of_error = t_critical * sem

lower_bound = mean - margin_of_error
upper_bound = mean + margin_of_error

print(f"Sample Mean = {mean:.2f}")
print(f"95% Confidence Interval = ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Sample Mean = 73.50
# 95% Confidence Interval = (71.33, 75.67)

# %% [markdown]
# **17.Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.**

# %%
import numpy as np
import scipy.stats as stats

np.random.seed(42)
mu_true = 50
sigma_true = 10
n = 40

data = np.random.normal(loc=mu_true, scale=sigma_true, size=n)


sample_mean = np.mean(data)
sample_sem = stats.sem(data)


confidence = 0.95
df = n - 1
t_critical = stats.t.ppf((1 + confidence) / 2, df)


margin_of_error = t_critical * sample_sem
ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

print(f"Sample Mean = {sample_mean:.2f}")
print(f"95% Confidence Interval = ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Sample Mean = 47.81
# 95% Confidence Interval = (44.77, 50.86)

# %% [markdown]
# **18.Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

mu = 0
sigma = 1

x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)


pdf_values = norm.pdf(x, loc=mu, scale=sigma)

plt.figure(figsize=(8, 5))
plt.plot(x, pdf_values, label=f'N({mu}, {sigma}²)', color='blue')
plt.title('Probability Density Function of Normal Distribution')
plt.xlabel('x')
plt.ylabel('PDF')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **19.Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.**

# %%
import numpy as np
from scipy.stats import poisson
import matplotlib.pyplot as plt

lambda_val = 4
k = 5

cdf_value = poisson.cdf(k, mu=lambda_val)

print(f"P(X ≤ {k}) for Poisson(λ={lambda_val}) = {cdf_value:.4f}")


x = np.arange(0, 15)
cdf_vals = poisson.cdf(x, mu=lambda_val)

plt.figure(figsize=(8, 5))
plt.step(x, cdf_vals, where='post', label=f'Poisson CDF (λ={lambda_val})')
plt.title('CDF of Poisson Distribution')
plt.xlabel('Number of Events (k)')
plt.ylabel('Cumulative Probability')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# P(X ≤ 5) for Poisson(λ=4) = 0.7851

# %% [markdown]
# **20.Simulate a random variable using a continuous uniform distribution and calculate its expected value.**

# %%
import numpy as np


a = 10
b = 20
n = 10000
samples = np.random.uniform(low=a, high=b, size=n)


sample_mean = np.mean(samples)

theoretical_mean = (a + b) / 2


print(f"Theoretical Expected Value: {theoretical_mean}")
print(f"Sample Mean (from simulation): {sample_mean:.4f}")
# Out:
# Theoretical Expected Value: 15.0
# Sample Mean (from simulation): 14.9443

# %% [markdown]
# **21.Write a Python program to compare the standard deviations of two datasets and visualize the difference.**

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

data_A = np.random.normal(loc=50, scale=5, size=1000)

data_B = np.random.normal(loc=50, scale=15, size=1000)

std_A = np.std(data_A, ddof=1)
std_B = np.std(data_B, ddof=1)

print(f"Standard Deviation of Dataset A: {std_A:.2f}")
print(f"Standard Deviation of Dataset B: {std_B:.2f}")

plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.boxplot([data_A, data_B], labels=['Dataset A', 'Dataset B'])
plt.title('Boxplot of Datasets')
plt.ylabel('Values')

plt.subplot(1, 2, 2)
plt.hist(data_A, bins=30, alpha=0.6, label='Dataset A', color='blue')
plt.hist(data_B, bins=30, alpha=0.6, label='Dataset B', color='orange')
plt.title('Histogram of Datasets')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Standard Deviation of Dataset A: 4.90
# Standard Deviation of Dataset B: 14.96
# <ipython-input-36-33472043a9ec>:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data_A, data_B], labels=['Dataset A', 'Dataset B'])

# %% [markdown]
# **22.Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.**

# %%
import numpy as np


np.random.seed(42)
mu = 100
sigma = 15
n = 1000

data = np.random.normal(loc=mu, scale=sigma, size=n)

data_range = np.max(data) - np.min(data)

q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1

print(f"Range of the dataset: {data_range:.2f}")
print(f"Interquartile Range (IQR): {iqr:.2f}")
# Out:
# Range of the dataset: 106.41
# Interquartile Range (IQR): 19.43

# %% [markdown]
# **23.Implement Z-score normalization on a dataset and visualize its transformation.**

# %%
import numpy as np
import matplotlib.pyplot as plt


np.random.seed(42)
data = np.random.normal(loc=100, scale=20, size=1000)


mean = np.mean(data)
std = np.std(data)
z_normalized_data = (data - mean) / std


print(f"Original Mean: {mean:.2f}, Std Dev: {std:.2f}")
print(f"Normalized Mean: {np.mean(z_normalized_data):.2f}, Std Dev: {np.std(z_normalized_data):.2f}")

plt.figure(figsize=(10, 5))


plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.title("Original Data")
plt.xlabel("Value")
plt.ylabel("Frequency")

plt.subplot(1, 2, 2)
plt.hist(z_normalized_data, bins=30, color='salmon', edgecolor='black')
plt.title("Z-score Normalized Data")
plt.xlabel("Z-score")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()
# Out:
# Original Mean: 100.39, Std Dev: 19.57
# Normalized Mean: -0.00, Std Dev: 1.00

# %% [markdown]
# **24.Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.**

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def analyze_normal_distribution_skew_kurt(mu=0, sigma=1, size=1000, fisher=True):

    data = np.random.normal(loc=mu, scale=sigma, size=size)

    data_skewness = skew(data)
    data_kurtosis = kurtosis(data, fisher=fisher)


    print(f"Skewness: {data_skewness:.4f}")
    if fisher:
        print(f"Kurtosis (Excess): {data_kurtosis:.4f}  → Normal if ≈ 0")
    else:
        print(f"Kurtosis (Pearson): {data_kurtosis:.4f} → Normal if ≈ 3")

    return {
        "skewness": data_skewness,
        "kurtosis": data_kurtosis
    }


analyze_normal_distribution_skew_kurt(mu=0, sigma=1, size=1000, fisher=True)
# Out:
# Skewness: -0.0493
# Kurtosis (Excess): 0.0521  → Normal if ≈ 0
# {'skewness': np.float64(-0.049321773965299257),
#  'kurtosis': np.float64(0.05211754569784022)}

# %% [markdown]
# #**Practical Part - 2**

# %% [markdown]
# **1.Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.**

# %%
import numpy as np
from scipy.stats import norm

def z_test(sample_data, population_mean, population_std, alpha=0.05):

    n = len(sample_data)
    sample_mean = np.mean(sample_data)


    z_stat = (sample_mean - population_mean) / (population_std / np.sqrt(n))

    p_value = 2 * (1 - norm.cdf(abs(z_stat)))


    print(f"Sample mean = {sample_mean:.4f}")
    print(f"Population mean = {population_mean}")
    print(f"Z-statistic = {z_stat:.4f}")
    print(f"P-value = {p_value:.4f}")


    if p_value < alpha:
        print(f"Reject the null hypothesis at α = {alpha}.")
        print("There is significant evidence that the sample mean differs from the population mean.")
    else:
        print(f"Fail to reject the null hypothesis at α = {alpha}.")
        print("There is not enough evidence to say the sample mean differs from the population mean.")

    return z_stat, p_value


np.random.seed(0)
sample = np.random.normal(loc=52, scale=10, size=40)
pop_mean = 50
pop_std = 10

z_test(sample, pop_mean, pop_std, alpha=0.05)
# Out:
# Sample mean = 55.1254
# Population mean = 50
# Z-statistic = 3.2416
# P-value = 0.0012
# Reject the null hypothesis at α = 0.05.
# There is significant evidence that the sample mean differs from the population mean.
# (np.float64(3.241603225877914), np.float64(0.0011885937948921121))

# %% [markdown]
# **2.Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.**

# %%
import numpy as np
from scipy.stats import ttest_ind


np.random.seed(42)
group1 = np.random.normal(loc=50, scale=8, size=30)
group2 = np.random.normal(loc=54, scale=8, size=30)

t_stat, p_value = ttest_ind(group1, group2, equal_var=True)

print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The means are significantly different.")
else:
    print("Fail to reject the null hypothesis: No significant difference between means.")
# Out:
# T-statistic: -2.3981
# P-value: 0.0197
# Reject the null hypothesis: The means are significantly different.

# %% [markdown]
# **3.Implement a one-sample Z-test using Python to compare the sample mean with the population mean.**

# %%
import numpy as np
from scipy.stats import norm

def one_sample_z_test(sample, pop_mean, pop_std, alpha=0.05):

    n = len(sample)
    sample_mean = np.mean(sample)

    z_stat = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))


    p_value = 2 * (1 - norm.cdf(abs(z_stat)))


    print(f"Sample mean: {sample_mean:.4f}")
    print(f"Population mean: {pop_mean}")
    print(f"Z statistic: {z_stat:.4f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < alpha:
        print(f"Reject the null hypothesis at α = {alpha}.")
        print("Sample mean is significantly different from the population mean.")
    else:
        print(f"Fail to reject the null hypothesis at α = {alpha}.")
        print("No significant difference between sample and population mean.")

    return z_stat, p_value


np.random.seed(123)
sample_data = np.random.normal(loc=105, scale=15, size=50)
population_mean = 100
population_std = 15

one_sample_z_test(sample_data, population_mean, population_std)
# Out:
# Sample mean: 105.1991
# Population mean: 100
# Z statistic: 2.4509
# P-value: 0.0143
# Reject the null hypothesis at α = 0.05.
# Sample mean is significantly different from the population mean.
# (np.float64(2.450865863819779), np.float64(0.014251304991718117))

# %% [markdown]
# **4.Perform a two-tailed Z-test using Python and visualize the decision region on a plot.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def two_tailed_z_test_with_plot(sample, pop_mean, pop_std, alpha=0.05):
    n = len(sample)
    sample_mean = np.mean(sample)

    z_stat = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))


    p_value = 2 * (1 - norm.cdf(abs(z_stat)))

    print(f"Sample mean = {sample_mean:.4f}")
    print(f"Population mean = {pop_mean}")
    print(f"Z-statistic = {z_stat:.4f}")
    print(f"P-value = {p_value:.4f}")

    z_crit = norm.ppf(1 - alpha / 2)
    print(f"Critical Z-value for alpha={alpha}: ±{z_crit:.4f}")

    x = np.linspace(-4, 4, 1000)
    y = norm.pdf(x)

    plt.figure(figsize=(10, 6))
    plt.plot(x, y, label='Standard Normal Distribution', color='blue')

    plt.fill_between(x, 0, y, where=(x <= -z_crit), color='red', alpha=0.5, label='Rejection Region (Left)')
    plt.fill_between(x, 0, y, where=(x >= z_crit), color='red', alpha=0.5, label='Rejection Region (Right)')

    plt.axvline(z_stat, color='green', linestyle='--', linewidth=2, label=f'Z Statistic = {z_stat:.2f}')

    plt.title('Two-tailed Z-test Decision Regions')
    plt.xlabel('Z-value')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()

    if abs(z_stat) > z_crit:
        print("Reject the null hypothesis: Sample mean significantly differs from population mean.")
    else:
        print("Fail to reject the null hypothesis: No significant difference detected.")

    return z_stat, p_value
np.random.seed(1)
sample_data = np.random.normal(loc=102, scale=15, size=40)  # Sample data
population_mean = 100
population_std = 15

two_tailed_z_test_with_plot(sample_data, population_mean, population_std, alpha=0.05)
# Out:
# Sample mean = 100.6560
# Population mean = 100
# Z-statistic = 0.2766
# P-value = 0.7821
# Critical Z-value for alpha=0.05: ±1.9600
# Fail to reject the null hypothesis: No significant difference detected.
# (np.float64(0.27660669596059273), np.float64(0.7820821226129591))

# %% [markdown]
# **5.Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_type1_type2_errors(mu0, mua, sigma, n, alpha=0.05):

    se = sigma / np.sqrt(n)


    z_crit = norm.ppf(1 - alpha/2)


    crit_low = mu0 - z_crit * se
    crit_high = mu0 + z_crit * se

    x = np.linspace(mu0 - 4*se, mua + 4*se, 1000)

    pdf_H0 = norm.pdf(x, loc=mu0, scale=se)
    pdf_Ha = norm.pdf(x, loc=mua, scale=se)

    plt.figure(figsize=(12,6))


    plt.plot(x, pdf_H0, label=r'$H_0$: $\mu = %.2f$' % mu0, color='blue')
    plt.plot(x, pdf_Ha, label=r'$H_a$: $\mu = %.2f$' % mua, color='orange')


    plt.fill_between(x, 0, pdf_H0, where=(x <= crit_low), color='red', alpha=0.3, label='Type 1 Error Region (α)')
    plt.fill_between(x, 0, pdf_H0, where=(x >= crit_high), color='red', alpha=0.3)


    plt.fill_between(x, 0, pdf_Ha, where=( (x > crit_low) & (x < crit_high) ), color='green', alpha=0.3, label='Type 2 Error Region (β)')


    plt.axvline(crit_low, color='red', linestyle='--')
    plt.axvline(crit_high, color='red', linestyle='--')

    plt.title('Type 1 (α) and Type 2 (β) Errors in Hypothesis Testing')
    plt.xlabel('Sample Mean')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()


    beta = norm.cdf(crit_high, loc=mua, scale=se) - norm.cdf(crit_low, loc=mua, scale=se)

    print(f"Significance level (Type 1 error α): {alpha:.3f}")
    print(f"Type 2 error (β): {beta:.3f}")
    print(f"Power of the test (1 - β): {1 - beta:.3f}")

    return alpha, beta, 1 - beta

plot_type1_type2_errors(mu0=100, mua=105, sigma=15, n=36, alpha=0.05)
# Out:
# Significance level (Type 1 error α): 0.050
# Type 2 error (β): 0.484
# Power of the test (1 - β): 0.516
# (0.05, np.float64(0.4839947260238248), np.float64(0.5160052739761751))

# %% [markdown]
# **6.Write a Python program to perform an independent T-test and interpret the results.**

# %%
import numpy as np
from scipy.stats import ttest_ind

def independent_t_test(sample1, sample2, alpha=0.05):

    t_stat, p_value = ttest_ind(sample1, sample2, equal_var=True)

    print(f"Group 1 mean = {np.mean(sample1):.3f}, std = {np.std(sample1, ddof=1):.3f}, n = {len(sample1)}")
    print(f"Group 2 mean = {np.mean(sample2):.3f}, std = {np.std(sample2, ddof=1):.3f}, n = {len(sample2)}")
    print(f"T-statistic = {t_stat:.4f}")
    print(f"P-value = {p_value:.4f}")

    if p_value < alpha:
        print(f"Reject the null hypothesis at α = {alpha}.")
        print("There is a statistically significant difference between the two groups.")
    else:
        print(f"Fail to reject the null hypothesis at α = {alpha}.")
        print("There is no statistically significant difference between the two groups.")

    return t_stat, p_value

np.random.seed(123)
group1 = np.random.normal(loc=20, scale=5, size=30)
group2 = np.random.normal(loc=22, scale=5, size=30)

independent_t_test(group1, group2, alpha=0.05)
# Out:
# Group 1 mean = 20.224, std = 5.936, n = 30
# Group 2 mean = 22.707, std = 6.163, n = 30
# T-statistic = -1.5899
# P-value = 0.1173
# Fail to reject the null hypothesis at α = 0.05.
# There is no statistically significant difference between the two groups.
# (np.float64(-1.5898880210619792), np.float64(0.11729667614087964))

# %% [markdown]
# **7.Perform a paired sample T-test using Python and visualize the comparison results.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel

def paired_t_test_with_plot(before, after, alpha=0.05):

    t_stat, p_value = ttest_rel(before, after)

    print(f"Mean before: {np.mean(before):.3f}")
    print(f"Mean after: {np.mean(after):.3f}")
    print(f"T-statistic: {t_stat:.4f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < alpha:
        print(f"Reject the null hypothesis at α = {alpha}.")
        print("Significant difference between before and after measurements.")
    else:
        print(f"Fail to reject the null hypothesis at α = {alpha}.")
        print("No significant difference detected.")


    plt.figure(figsize=(8,5))


    for i in range(len(before)):
        plt.plot([1, 2], [before[i], after[i]], marker='o', color='gray', alpha=0.6)


    means = [np.mean(before), np.mean(after)]
    std_errors = [np.std(before, ddof=1)/np.sqrt(len(before)),
                  np.std(after, ddof=1)/np.sqrt(len(after))]

    plt.errorbar([1, 2], means, yerr=std_errors, fmt='o', color='red', capsize=5, label='Mean ± SE')

    plt.xticks([1, 2], ['Before', 'After'])
    plt.ylabel('Measurements')
    plt.title('Paired Sample Comparison')
    plt.legend()
    plt.grid(True)
    plt.show()

    return t_stat, p_value

np.random.seed(42)
before_treatment = np.random.normal(loc=50, scale=5, size=20)
after_treatment = before_treatment + np.random.normal(loc=-3, scale=4, size=20)

paired_t_test_with_plot(before_treatment, after_treatment)
# Out:
# Mean before: 49.144
# Mean after: 45.080
# T-statistic: 4.6936
# P-value: 0.0002
# Reject the null hypothesis at α = 0.05.
# Significant difference between before and after measurements.
# (np.float64(4.693592105020693), np.float64(0.0001581936123198657))

# %% [markdown]
# **8.Simulate data and perform both Z-test and T-test, then compare the results using Python.**

# %%
import numpy as np
from scipy.stats import norm, t, ttest_1samp

def one_sample_z_test(sample, pop_mean, pop_std):
    n = len(sample)
    sample_mean = np.mean(sample)
    z_stat = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
    p_value = 2 * (1 - norm.cdf(abs(z_stat)))
    return z_stat, p_value

def one_sample_t_test(sample, pop_mean):
    t_stat, p_value = ttest_1samp(sample, pop_mean)
    return t_stat, p_value

np.random.seed(0)
pop_mean = 100
pop_std = 15

sample_size = 30
sample_data = np.random.normal(loc=102, scale=pop_std, size=sample_size)  # sample mean slightly different

z_stat, z_p = one_sample_z_test(sample_data, pop_mean, pop_std)

t_stat, t_p = one_sample_t_test(sample_data, pop_mean)

print(f"Sample mean = {np.mean(sample_data):.3f}, Sample std = {np.std(sample_data, ddof=1):.3f}, n = {sample_size}")
print("\nOne-sample Z-test (known population std):")
print(f"  Z statistic = {z_stat:.4f}")
print(f"  P-value = {z_p:.4f}")

print("\nOne-sample T-test (sample std):")
print(f"  T statistic = {t_stat:.4f}")
print(f"  P-value = {t_p:.4f}")


alpha = 0.05
print("\nInterpretation at alpha = 0.05:")
if z_p < alpha:
    print("Z-test: Reject null hypothesis — sample mean significantly differs from population mean.")
else:
    print("Z-test: Fail to reject null hypothesis.")

if t_p < alpha:
    print("T-test: Reject null hypothesis — sample mean significantly differs from population mean.")
else:
    print("T-test: Fail to reject null hypothesis.")
# Out:
# Sample mean = 108.643, Sample std = 16.505, n = 30
#
# One-sample Z-test (known population std):
#   Z statistic = 3.1559
#   P-value = 0.0016
#
# One-sample T-test (sample std):
#   T statistic = 2.8682
#   P-value = 0.0076
#
# Interpretation at alpha = 0.05:
# Z-test: Reject null hypothesis — sample mean significantly differs from population mean.
# T-test: Reject null hypothesis — sample mean significantly differs from population mean.

# %% [markdown]
# **9.Write a Python function to calculate the confidence interval for a sample mean and explain its significance.**

# %%
import numpy as np
from scipy.stats import t

def confidence_interval(sample, confidence=0.95):

    n = len(sample)
    mean = np.mean(sample)
    std_err = np.std(sample, ddof=1) / np.sqrt(n)


    t_crit = t.ppf((1 + confidence) / 2, df=n-1)

    margin_of_error = t_crit * std_err
    lower_bound = mean - margin_of_error
    upper_bound = mean + margin_of_error

    return mean, lower_bound, upper_bound


np.random.seed(123)
sample_data = np.random.normal(loc=50, scale=10, size=40)

mean, lower, upper = confidence_interval(sample_data, confidence=0.95)
print(f"Sample mean = {mean:.2f}")
print(f"95% confidence interval = ({lower:.2f}, {upper:.2f})")
# Out:
# Sample mean = 49.17
# 95% confidence interval = (45.39, 52.94)

# %% [markdown]
# **10.Write a Python program to calculate the margin of error for a given confidence level using sample data.**

# %%
import numpy as np
from scipy.stats import t

def margin_of_error(sample, confidence=0.95):

    n = len(sample)
    std_err = np.std(sample, ddof=1) / np.sqrt(n)  # standard error of mean
    t_crit = t.ppf((1 + confidence) / 2, df=n-1)  # t critical value

    moe = t_crit * std_err
    return moe


np.random.seed(42)
sample_data = np.random.normal(loc=100, scale=15, size=50)

moe = margin_of_error(sample_data, confidence=0.95)
print(f"Margin of error at 95% confidence level: {moe:.3f}")
# Out:
# Margin of error at 95% confidence level: 3.980

# %% [markdown]
# **11.Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.**

# %%
def bayes_theorem(prior, likelihood, false_positive_rate):

    p_data = likelihood * prior + false_positive_rate * (1 - prior)


    posterior = (likelihood * prior) / p_data

    return posterior


prior = 0.01
likelihood = 0.99
false_positive_rate = 0.05

posterior = bayes_theorem(prior, likelihood, false_positive_rate)

print(f"Prior probability (disease prevalence): {prior:.3f}")
print(f"Likelihood (test sensitivity): {likelihood:.3f}")
print(f"False positive rate: {false_positive_rate:.3f}")
print(f"Posterior probability (disease given positive test): {posterior:.3f}")
# Out:
# Prior probability (disease prevalence): 0.010
# Likelihood (test sensitivity): 0.990
# False positive rate: 0.050
# Posterior probability (disease given positive test): 0.167

# %% [markdown]
# **12.Perform a Chi-square test for independence between two categorical variables in Python.**

# %%
import numpy as np
from scipy.stats import chi2_contingency


data = np.array([[30, 10],
                 [20, 40]])


chi2_stat, p_val, dof, expected = chi2_contingency(data)

print("Chi-square Statistic:", chi2_stat)
print("Degrees of Freedom:", dof)
print("P-value:", p_val)
print("Expected Frequencies:\n", expected)


alpha = 0.05
if p_val < alpha:
    print("Reject null hypothesis - variables are dependent.")
else:
    print("Fail to reject null hypothesis - no evidence of dependence.")
# Out:
# Chi-square Statistic: 15.041666666666666
# Degrees of Freedom: 1
# P-value: 0.00010516355403363098
# Expected Frequencies:
#  [[20. 20.]
#  [30. 30.]]
# Reject null hypothesis - variables are dependent.

# %% [markdown]
# **13.Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data.**

# %%
import numpy as np

def expected_frequencies(observed):

    observed = np.array(observed)
    row_sums = observed.sum(axis=1).reshape(-1, 1)
    col_sums = observed.sum(axis=0).reshape(1, -1)
    total = observed.sum()

    expected = (row_sums @ col_sums) / total
    return expected


observed_data = [
    [30, 10, 20],
    [20, 40, 25]
]

expected = expected_frequencies(observed_data)
print("Observed frequencies:\n", np.array(observed_data))
print("Expected frequencies:\n", expected)
# Out:
# Observed frequencies:
#  [[30 10 20]
#  [20 40 25]]
# Expected frequencies:
#  [[20.68965517 20.68965517 18.62068966]
#  [29.31034483 29.31034483 26.37931034]]

# %% [markdown]
# **14.Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.**

# %%
import numpy as np
from scipy.stats import chisquare


observed = np.array([50, 30, 20])

expected_probs = np.array([0.4, 0.4, 0.2])

expected_counts = expected_probs * observed.sum()

chi2_stat, p_value = chisquare(f_obs=observed, f_exp=expected_counts)

print(f"Observed counts: {observed}")
print(f"Expected counts: {expected_counts}")
print(f"Chi-square Statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")


alpha = 0.05
if p_value < alpha:
    print("Reject null hypothesis: observed data does NOT fit the expected distribution.")
else:
    print("Fail to reject null hypothesis: observed data fits the expected distribution.")
# Out:
# Observed counts: [50 30 20]
# Expected counts: [40. 40. 20.]
# Chi-square Statistic: 5.0000
# P-value: 0.0821
# Fail to reject null hypothesis: observed data fits the expected distribution.
